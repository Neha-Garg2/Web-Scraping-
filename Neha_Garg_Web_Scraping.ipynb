# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha-Garg2/Web-Scraping-/blob/main/Neha_Garg_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping**

# %% [markdown]
# **IMPORT LIABRARIES**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **Request URL**

# %%
page = requests.get('https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobiles')

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# **Find content of webpage** &&
# **To print all "<a" tags**

# %%
m = soup.find_all('a')
m
# Out:
# [<a id="nav-top"></a>,
#  <a class="skip-link" id="skiplink" tabindex="3">Skip to main content</a>,
#  <a aria-label="Open Menu" href="/gp/site-directory?ref_=nav_em_js_disabled" id="nav-hamburger-menu" role="button" tabindex="5">
#  <i class="hm-icon nav-sprite"></i>
#  </a>,
#  <a aria-label="Amazon" class="nav-logo-link" href="/ref=nav_logo" tabindex="6">
#  <span class="nav-sprite nav-logo-base"></span>
#  <span class="nav-sprite nav-logo-ext"></span>
#  <span class="nav-logo-locale">.in</span>
#  </a>,
#  <a class="nav-a nav-a-2 icp-link-style-2" href="/gp/customer-preferences/select-language/ref=topnav_lang_t1?preferencesReturnUrl=%2F" id="icp-nav-flyout">
#  <span class="icp-nav-link-inner">
#  <span class="nav-line-1">
#  <span class="icp-nav-flag icp-nav-flag-in"></span>
#  </span>
#  <span class="nav-line-2">
#          <span class="nav-icon nav-arrow"></span>
#  </span>
#  </span>
#  </a>,
# ...

# %% [markdown]
# **To save content**

# %%
links = set()

for l in m:
    if (l.get('href') != '#'):
      lText = "https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobiles" + str(l.get('href'))
      links.add(l)
      print(lText)
# Out:
# https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobilesNone
# https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobilesNone
# https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobiles/gp/site-directory?ref_=nav_em_js_disabled
# https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobiles/ref=nav_logo
# https://www.amazon.in/mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobiles/gp/customer-preferences/select-language/ref=topnav_lang_t1?preferencesReturnUrl=%2F
# ...
